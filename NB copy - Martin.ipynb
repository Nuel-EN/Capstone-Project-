# %%
#Import package
import pandas as pd

# %%
#load Dataset
data_analyst_df = pd.read_csv('dataset/DataAnalyst.csv')
data_scientist_df = pd.read_csv('dataset/DataScientist.csv')
google_job = pd.read_csv('dataset/gsearch_jobs 3.csv')

# %%
data_analyst_df.head(2)
# Out:
#    unnamed:_0                                          job_title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      job_description  rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               company_name      location  headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#                    size  founded       type_of_ownership  \
# 0  201 to 500 employees     1961  Nonprofit Organization
# 1      10000+ employees     1893  Nonprofit Organization
#
#                            industry       sector                     revenue  \
# ...

# %%
#Rename Columns to lower and replace white spaces with Underscore
data_analyst_df.rename(columns=lambda x : x.lower(), inplace=True)
data_analyst_df.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)
data_scientist_df.rename(columns=lambda x : x.lower(), inplace=True)
data_scientist_df.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)
google_job.rename(columns=lambda x : x.lower(), inplace=True)
google_job.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)

google_job.rename(columns= {'title':'job_title', 'description':'job_description', 'description':'job_description'}, inplace=True)

# %%
data_scientist_df.head(2)
# Out:
#    unnamed:_0  index                          job_title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
#
#                 salary_estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
#
#                                      job_description  rating  company_name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5   Hopper\n3.5
# 1  At Noom, we use scientifically proven methods ...     4.5  Noom US\n4.5
#
#        location      headquarters                    size  founded  \
# 0  New York, NY  Montreal, Canada   501 to 1000 employees     2007
# 1  New York, NY      New York, NY  1001 to 5000 employees     2008
#
#    type_of_ownership                   industry             sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
#
#                     revenue competitors easy_apply
# ...

# %%
print(google_job.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1970 entries, 0 to 1969
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   unnamed:_0           1970 non-null   int64
#  1   index                1970 non-null   int64
#  2   job_title            1970 non-null   object
#  3   company_name         1970 non-null   object
#  4   location             1967 non-null   object
#  5   via                  1970 non-null   object
#  6   job_description      1970 non-null   object
#  7   extensions           1970 non-null   object
#  8   job_id               1970 non-null   object
#  9   thumbnail            1126 non-null   object
#  10  posted_at            1970 non-null   object
#  11  schedule_type        1961 non-null   object
#  12  work_from_home       993 non-null    object
#  13  salary               382 non-null    object
#  14  search_term          1970 non-null   object
# ...

# %%
google_job.head(15)
# Out:
#     unnamed:_0  index                                          job_title  \
# 0            0      0                                       Data Analyst
# 1            1      1                           Data Analyst (Marketing)
# 2            2      2  People Analytics Data Analyst (Talent Acquisit...
# 3            3      3                                       Data Analyst
# 4            4      4                            Sr Systems Data Analyst
# 5            5      5  Product Information Management (PIM) Data Analyst
# 6            6      6                  Provider Maintenance Data Analyst
# 7            7      7                 Data Analyst, Education & Services
# 8            8      8  Sr. Healthcare & Accounting Data Modeler and A...
# 9            9      9                               Analyst III - REMOTE
# 10          10     10                Data Analyst, Business Intelligence
# 11          11     11                                       Data Analyst
# ...

# %%
#drop columns
data_analyst_df2=data_analyst_df.drop(columns= ['unnamed:_0', 'rating', 'company_name', 'location', 'headquarters', 'founded', 'competitors', 'easy_apply' ], axis=1)
data_scientist_df2=data_scientist_df.drop(columns= ['unnamed:_0', 'rating', 'company_name', 'location', 'headquarters', 'founded', 'competitors', 'easy_apply' ], axis=1)
google_job_df2=google_job.drop(columns= ['unnamed:_0', 'company_name', 'location', 'via', 'extensions', 'job_id', 'thumbnail', 'posted_at', 'search_term', 'date_time', 'search_location', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized' ], axis=1)

# %%
google_job_df2.head()
# Out:
#    index                                          job_title  \
# 0      0                                       Data Analyst
# 1      1                           Data Analyst (Marketing)
# 2      2  People Analytics Data Analyst (Talent Acquisit...
# 3      3                                       Data Analyst
# 4      4                            Sr Systems Data Analyst
#
#                                      job_description schedule_type  \
# 0  Job Posting Title\nData Analyst\n...\nAgency\n...     Full-time
# 1  About The Role\n\nAbout Us...\n\nWe’re Entain....     Full-time
# 2  Job Description\nPeople Analytics CoE (Communi...     Full-time
# 3  Pernod Ricard is now hiring Data Analyst in Un...     Full-time
# 4  Type of Requisition: Regular\n\nClearance Leve...     Full-time
#
#   work_from_home      salary  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN  20 an hour
# 4            NaN         NaN
#
# ...

# %%
data_analyst_df_12 = data_analyst_df.rename_axis('index').reset_index()

data_analyst_df_12
# Out:
#       index  unnamed:_0                                          job_title  \
# 0         0           0  Data Analyst, Center on Immigration and Justic...
# 1         1           1                               Quality Data Analyst
# 2         2           2  Senior Data Analyst, Insights & Analytics Team...
# 3         3           3                                       Data Analyst
# 4         4           4                             Reporting Data Analyst
# ...     ...         ...                                                ...
# 2248   2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249   2249        2249              Senior Data Analyst (Corporate Audit)
# 2250   2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251   2251        2251                Data Analyst 3, Customer Experience
# 2252   2252        2252                        Senior Quality Data Analyst
#
#                   salary_estimate  \
# ...

# %%
df_c1 = pd.DataFrame(data_analyst_df2.columns)

df_c1
# Out:
#                    0
# 0          job_title
# 1    salary_estimate
# 2    job_description
# 3               size
# 4  type_of_ownership
# 5           industry
# 6             sector
# 7            revenue

# %%
df_c2 = pd.DataFrame(data_scientist_df2.columns)

df_c2
# Out:
#                    0
# 0              index
# 1          job_title
# 2    salary_estimate
# 3    job_description
# 4               size
# 5  type_of_ownership
# 6           industry
# 7             sector
# 8            revenue

# %%
df_c3 = pd.DataFrame(google_job_df2.columns)

df_c3
# Out:
#                     0
# 0               index
# 1           job_title
# 2     job_description
# 3       schedule_type
# 4      work_from_home
# 5              salary
# 6  description_tokens

# %%
pd.concat([df_c1, df_c2, df_c3], axis=1)
# Out:
#                    0                  0                   0
# 0          job_title              index               index
# 1    salary_estimate          job_title           job_title
# 2    job_description    salary_estimate     job_description
# 3               size    job_description       schedule_type
# 4  type_of_ownership               size      work_from_home
# 5           industry  type_of_ownership              salary
# 6             sector           industry  description_tokens
# 7            revenue             sector                 NaN
# 8                NaN            revenue                 NaN

# %%
MasterTable_df = pd.concat([data_analyst_df2, data_scientist_df2, google_job_df2], keys=["DA_df", "DS_df", "G_df"])

MasterTable_df
# Out:
#                                                     job_title  \
# DA_df 0     Data Analyst, Center on Immigration and Justic...
#       1                                  Quality Data Analyst
#       2     Senior Data Analyst, Insights & Analytics Team...
#       3                                          Data Analyst
#       4                                Reporting Data Analyst
# ...                                                       ...
# G_df  1965        Senior Performance Marketing (Data Analyst)
#       1966                 Data Analyst, Developer Operations
#       1967  Data Science/Data Analyst Internship - Summer ...
#       1968            2023 Internship- Associate Data Analyst
#       1969                                   Jr. Data Analyst
#
#                        salary_estimate  \
# DA_df 0     $37K-$66K (Glassdoor est.)
#       1     $37K-$66K (Glassdoor est.)
#       2     $37K-$66K (Glassdoor est.)
#       3     $37K-$66K (Glassdoor est.)
# ...

# %%
MasterTable_df.loc["DS_df"]
# Out:
#                                               job_title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 3904                                  AWS Data Engineer
# 3905                              Data Analyst â Junior
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                    salary_estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# ...

# %%
CoHead_MasterTable_df= pd.DataFrame(MasterTable_df.loc["DS_df"].columns)

CoHead_MasterTable_df
# Out:
#                      0
# 0            job_title
# 1      salary_estimate
# 2      job_description
# 3                 size
# 4    type_of_ownership
# 5             industry
# 6               sector
# 7              revenue
# 8                index
# 9        schedule_type
# 10      work_from_home
# 11              salary
# 12  description_tokens

# %%
CoHead_MasterTable_df= pd.DataFrame(MasterTable_df.loc["DS_df"].columns)

df_c2 = pd.DataFrame(data_scientist_df2.columns)

# %%
pd.concat([ df_c3, df_c2, df_c1, CoHead_MasterTable_df], axis=1)
# Out:
#                      0                  0                  0  \
# 0                index              index          job_title
# 1            job_title          job_title    salary_estimate
# 2      job_description    salary_estimate    job_description
# 3        schedule_type    job_description               size
# 4       work_from_home               size  type_of_ownership
# 5               salary  type_of_ownership           industry
# 6   description_tokens           industry             sector
# 7                  NaN             sector            revenue
# 8                  NaN            revenue                NaN
# 9                  NaN                NaN                NaN
# 10                 NaN                NaN                NaN
# 11                 NaN                NaN                NaN
# 12                 NaN                NaN                NaN
#
#                      0
# 0            job_title
# 1      salary_estimate
# 2      job_description
# ...
