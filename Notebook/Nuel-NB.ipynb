# %% [markdown]
# # Packages

# %%
#Import package
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
#load Dataset
data_analyst_df = pd.read_csv('/Users/nuel/neuefische/Capstone-Project-/dataset/DataAnalyst.csv')
data_scientist_df = pd.read_csv('/Users/nuel/neuefische/Capstone-Project-/dataset/DataScientist.csv')
google_job = pd.read_csv('/Users/nuel/neuefische/Capstone-Project-/dataset/gsearch_jobs 3.csv')

# %%
data_analyst_df.head(2)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#
#                    Size  Founded       Type of ownership  \
# 0  201 to 500 employees     1961  Nonprofit Organization
# 1      10000+ employees     1893  Nonprofit Organization
#
#                            Industry       Sector                     Revenue  \
# ...

# %% [markdown]
# # Rename Columns, Lower case...

# %%
#Rename Columns to lower and replace white spaces with Underscore
data_analyst_df.rename(columns=lambda x : x.lower(), inplace=True)
data_analyst_df.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)
data_scientist_df.rename(columns=lambda x : x.lower(), inplace=True)
data_scientist_df.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)
google_job.rename(columns=lambda x : x.lower(), inplace=True)
google_job.rename(columns=lambda x : x.replace(' ', '_'), inplace=True)

# %%
data_scientist_df.head(2)
# Out:
#    unnamed:_0  index                          job_title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
#
#                 salary_estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
#
#                                      job_description  rating  company_name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5   Hopper\n3.5
# 1  At Noom, we use scientifically proven methods ...     4.5  Noom US\n4.5
#
#        location      headquarters                    size  founded  \
# 0  New York, NY  Montreal, Canada   501 to 1000 employees     2007
# 1  New York, NY      New York, NY  1001 to 5000 employees     2008
#
#    type_of_ownership                   industry             sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
#
#                     revenue competitors easy_apply
# ...

# %%
data_scientist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   unnamed:_0         3909 non-null   int64
#  1   index              3909 non-null   int64
#  2   job_title          3909 non-null   object
#  3   salary_estimate    3909 non-null   object
#  4   job_description    3909 non-null   object
#  5   rating             3909 non-null   float64
#  6   company_name       3909 non-null   object
#  7   location           3909 non-null   object
#  8   headquarters       3909 non-null   object
#  9   size               3909 non-null   object
#  10  founded            3909 non-null   int64
#  11  type_of_ownership  3909 non-null   object
#  12  industry           3909 non-null   object
#  13  sector             3909 non-null   object
#  14  revenue            3909 non-null   object
#  15  competitors        3909 non-null   object
# ...

# %%
data_scientist_df.job_title.unique()
# Out:
# array(['Senior Data Scientist', 'Data Scientist, Product Analytics',
#        'Data Science Manager', ..., 'Cyber Security Data Engineer',
#        'Security Analytics Data Engineer',
#        'Patient Safety Physician or Safety Scientist - UK, Europe or the US'],
#       dtype=object)

# %% [markdown]
# google_job.head(2)

# %%
google_job.salary_max.unique()
# Out:
# array([          nan, 1.3076400e+05, 7.0000000e+01, 1.3366500e+05,
#        1.0000000e+05, 8.3700000e+04, 6.0000000e+01, 1.1047290e+05,
#        6.5000000e+01, 2.2000000e+01, 5.0000000e+01, 1.1000000e+05,
#        1.3000000e+05, 5.5000000e+01, 1.1050100e+05, 1.1051390e+05,
#        6.0000000e+04, 1.2000000e+05, 1.5431300e+05, 4.0000000e+01,
#        3.5000000e+01, 4.5000000e+01, 1.2000000e+01, 3.0000000e+01,
#        8.0000000e+01, 2.5000000e+01, 2.8000000e+01, 1.5000000e+01,
#        7.5000000e+01, 1.0000000e+02, 2.0000000e+01, 9.0000000e+01,
#        1.2500000e+02, 1.1500000e+02, 3.3000000e+01, 9.7000000e+01,
#        1.5000000e+02, 8.5000000e+01, 1.2500000e+05, 2.3200000e+05,
#        7.5000000e+04, 1.1400000e+05, 2.5000000e+05, 2.2000000e+05,
#        2.2300000e+05, 1.0700000e+05, 1.6200000e+05, 6.3000000e+01,
#        6.8000000e+01, 6.1000000e+01, 6.2000000e+01, 6.5000000e+04,
#        6.0000000e+03, 1.4000000e+05, 9.0000000e+04, 9.7877880e+04,
# ...

# %% [markdown]
# # Drop Columns

# %%
#drop columns
data_analyst_df2=data_analyst_df.drop(columns= ['unnamed:_0', 'rating', 'company_name', 'location', 'headquarters', 'founded', 'competitors', 'easy_apply' ], axis=1)
data_scientist_df2=data_scientist_df.drop(columns= ['unnamed:_0', 'rating', 'company_name', 'location', 'headquarters', 'founded', 'competitors', 'easy_apply' ], axis=1)
google_job_df2=google_job.drop(columns= ['unnamed:_0', 'company_name', 'location', 'via', 'extensions', 'job_id', 'thumbnail', 'posted_at', 'search_term', 'date_time', 'search_location', 'commute_time', 'salary_pay', 'salary_rate', 'salary_avg', 'salary_min', 'salary_max', 'salary_hourly', 'salary_yearly', 'salary_standardized' ], axis=1)

# %%
google_job_df2.head()
# Out:
#    index                                              title  \
# 0      0                                       Data Analyst
# 1      1                           Data Analyst (Marketing)
# 2      2  People Analytics Data Analyst (Talent Acquisit...
# 3      3                                       Data Analyst
# 4      4                            Sr Systems Data Analyst
#
#                                          description schedule_type  \
# 0  Job Posting Title\nData Analyst\n...\nAgency\n...     Full-time
# 1  About The Role\n\nAbout Us...\n\nWe’re Entain....     Full-time
# 2  Job Description\nPeople Analytics CoE (Communi...     Full-time
# 3  Pernod Ricard is now hiring Data Analyst in Un...     Full-time
# 4  Type of Requisition: Regular\n\nClearance Leve...     Full-time
#
#   work_from_home      salary  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN  20 an hour
# 4            NaN         NaN
#
# ...

# %%
data_scientist_df2.head(2)
# Out:
#    index                          job_title               salary_estimate  \
# 0      0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1      1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
#
#                                      job_description                    size  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...   501 to 1000 employees
# 1  At Noom, we use scientifically proven methods ...  1001 to 5000 employees
#
#    type_of_ownership                   industry             sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
#
#                     revenue
# 0  Unknown / Non-Applicable
# 1  Unknown / Non-Applicable

# %%
google_job_df2.columns
# Out:
# Index(['index', 'title', 'description', 'schedule_type', 'work_from_home',
#        'salary', 'description_tokens'],
#       dtype='object')

# %%
data_analyst_df2.columns
# Out:
# Index(['job_title', 'salary_estimate', 'job_description', 'size',
#        'type_of_ownership', 'industry', 'sector', 'revenue'],
#       dtype='object')

# %%
data_analyst_df2 = data_analyst_df2.rename_axis('index').reset_index()

# %%
pd.DataFrame(data_analyst_df2.columns, data_scientist_df2.columns)
# Out:
#                                    0
# index                          index
# job_title                  job_title
# salary_estimate      salary_estimate
# job_description      job_description
# size                            size
# type_of_ownership  type_of_ownership
# industry                    industry
# sector                        sector
# revenue                      revenue

# %% [markdown]
# # Join Data Analyst Dataset and Data Scientis Dataset

# %%
#Join Data Analyst Dataset and Data Scientist Dataset
analyst_scientist_df = pd.concat([data_analyst_df2, data_scientist_df2])

# %%
analyst_scientist_df.head(2)
# Out:
#    index                                          job_title  \
# 0      0  Data Analyst, Center on Immigration and Justic...
# 1      1                               Quality Data Analyst
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      job_description                  size  \
# 0  Are you eager to roll up your sleeves and harn...  201 to 500 employees
# 1  Overview\n\nProvides analytical and technical ...      10000+ employees
#
#         type_of_ownership                          industry       sector  \
# 0  Nonprofit Organization                 Social Assistance   Non-Profit
# 1  Nonprofit Organization  Health Care Services & Hospitals  Health Care
#
#                       revenue
# 0  $100 to $500 million (USD)
# 1      $2 to $5 billion (USD)

# %%
analyst_scientist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6162 entries, 0 to 3908
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              6162 non-null   int64
#  1   job_title          6162 non-null   object
#  2   salary_estimate    6162 non-null   object
#  3   job_description    6162 non-null   object
#  4   size               6162 non-null   object
#  5   type_of_ownership  6162 non-null   object
#  6   industry           6162 non-null   object
#  7   sector             6162 non-null   object
#  8   revenue            6162 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 481.4+ KB

# %%
display(pd.DataFrame(analyst_scientist_df.columns))
display(pd.DataFrame(google_job_df2.columns))
# Out:
#                    0
# 0              index
# 1          job_title
# 2    salary_estimate
# 3    job_description
# 4               size
# 5  type_of_ownership
# 6           industry
# 7             sector
# 8            revenue
#                     0
# 0               index
# 1               title
# 2         description
# 3       schedule_type
# 4      work_from_home
# 5              salary
# 6  description_tokens

# %% [markdown]
# # Rename Columns for the google Job Dataset

# %%
#lets rename columns of the google job dataset
google_job_df3 = google_job_df2.rename(columns={'title': 'job_title', 'description': 'job_description'})

# %%
google_job_df3.head(2)
# Out:
#    index                 job_title  \
# 0      0              Data Analyst
# 1      1  Data Analyst (Marketing)
#
#                                      job_description schedule_type  \
# 0  Job Posting Title\nData Analyst\n...\nAgency\n...     Full-time
# 1  About The Role\n\nAbout Us...\n\nWe’re Entain....     Full-time
#
#   work_from_home salary                       description_tokens
# 0            NaN    NaN                                   ['go']
# 1            NaN    NaN  ['sql', 'tableau', 'python', 'r', 'go']

# %% [markdown]
# # join Google Dataset to the Data analyst and Scientist Dataset

# %%
#join google dataset to the data analyst /scientist dataset
master_df = pd.concat([analyst_scientist_df, google_job_df3])

# %%
master_df.head(3)
# Out:
#    index                                          job_title  \
# 0      0  Data Analyst, Center on Immigration and Justic...
# 1      1                               Quality Data Analyst
# 2      2  Senior Data Analyst, Insights & Analytics Team...
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      job_description                    size  \
# 0  Are you eager to roll up your sleeves and harn...    201 to 500 employees
# 1  Overview\n\nProvides analytical and technical ...        10000+ employees
# 2  We’re looking for a Senior Data Analyst who ha...  1001 to 5000 employees
#
#         type_of_ownership                          industry  \
# 0  Nonprofit Organization                 Social Assistance
# 1  Nonprofit Organization  Health Care Services & Hospitals
# 2       Company - Private                          Internet
#
# ...

# %%
pd.DataFrame(master_df.columns)
# Out:
#                      0
# 0                index
# 1            job_title
# 2      salary_estimate
# 3      job_description
# 4                 size
# 5    type_of_ownership
# 6             industry
# 7               sector
# 8              revenue
# 9        schedule_type
# 10      work_from_home
# 11              salary
# 12  description_tokens

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8132 entries, 0 to 1969
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               8132 non-null   int64
#  1   job_title           8132 non-null   object
#  2   salary_estimate     6162 non-null   object
#  3   job_description     8132 non-null   object
#  4   size                6162 non-null   object
#  5   type_of_ownership   6162 non-null   object
#  6   industry            6162 non-null   object
#  7   sector              6162 non-null   object
#  8   revenue             6162 non-null   object
#  9   schedule_type       1961 non-null   object
#  10  work_from_home      993 non-null    object
#  11  salary              382 non-null    object
#  12  description_tokens  1970 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 889.4+ KB

# %%
#da_or_dss = []
#words = 'Data Analyst', 'Data Scientist'
#for i in master_df['job_title']:
 #   for j in words:
#        if j in i:
#            #data = j
#            da_ds = da_or_dss.append(j)
#            #print(da_or_dss)
#        else:
#            da_ds = da_or_dss.append('others')

# %%
#words = 'data analyst', 'data scientist', 'Data Analyst', 'Data Scientist'
#for i in list(master_df.job_title):
#    for j in words:
#        if j in i:
#            dat = pd.DataFrame()
#            dat['dat2'] = [j]
#        else:
#            dat = pd.DataFrame()
#            dat['dat2'] = 'others'
#            master = master_df.append(dat)

# %% [markdown]
# # Tokenization

# %%
master_df.head(2)
# Out:
#    index                                          job_title  \
# 0      0  Data Analyst, Center on Immigration and Justic...
# 1      1                               Quality Data Analyst
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      job_description                  size  \
# 0  Are you eager to roll up your sleeves and harn...  201 to 500 employees
# 1  Overview\n\nProvides analytical and technical ...      10000+ employees
#
#         type_of_ownership                          industry       sector  \
# 0  Nonprofit Organization                 Social Assistance   Non-Profit
# 1  Nonprofit Organization  Health Care Services & Hospitals  Health Care
#
#                       revenue schedule_type work_from_home salary  \
# 0  $100 to $500 million (USD)           NaN            NaN    NaN
# 1      $2 to $5 billion (USD)           NaN            NaN    NaN
#
#   description_tokens
# ...

# %%
master_token_df = master_df
master_token_df.job_title = master_token_df.job_title.str.lower()
master_token_df.head(2)
# Out:
#    index                                          job_title  \
# 0      0  data analyst, center on immigration and justic...
# 1      1                               quality data analyst
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
#
#                                      job_description                  size  \
# 0  Are you eager to roll up your sleeves and harn...  201 to 500 employees
# 1  Overview\n\nProvides analytical and technical ...      10000+ employees
#
#         type_of_ownership                          industry       sector  \
# 0  Nonprofit Organization                 Social Assistance   Non-Profit
# 1  Nonprofit Organization  Health Care Services & Hospitals  Health Care
#
#                       revenue schedule_type work_from_home salary  \
# 0  $100 to $500 million (USD)           NaN            NaN    NaN
# 1      $2 to $5 billion (USD)           NaN            NaN    NaN
#
#   description_tokens
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
master_token_df['title_split'] = master_token_df['job_title'].apply(word_tokenize)
#master_token_df['title_split'] = master_token_df['job_title']

# %%
master_token_df.title_split.head()
# Out:
# 0    [data, analyst, ,, center, on, immigration, an...
# 1                             [quality, data, analyst]
# 2    [senior, data, analyst, ,, insights, &, analyt...
# 3                                      [data, analyst]
# 4                           [reporting, data, analyst]
# Name: title_split, dtype: object

# %%
#my_keywords = ['data, analyst', 'data, scientist', 'bi, analyst',  'financial, analyst','data, science, analyst', 'data, science', 'business, analyst', 'data, science, analyst', 'associate, scientist']
#my_keywords = ['data', 'analyst', 'data analyst', 'data scientist', 'bi analyst',  'financial analyst','data science analyst', 'data science', 'business analyst', 'data science analyst', 'associate scientist']
my_keywords = ['data', 'scientist', 'analytics', 'analyst', 'science' ]

# %%
master_token_df['title_split'] = (master_token_df['title_split'].apply(lambda x: [title for title in x if title in my_keywords]))
#master_token_df['title_split'] = (master_token_df['job_title'].apply(lambda x: [title for title in x if title in my_keywords]))

# %%
master_token_df.head(20)
# Out:
#     index                                          job_title  \
# 0       0  data analyst, center on immigration and justic...
# 1       1                               quality data analyst
# 2       2  senior data analyst, insights & analytics team...
# 3       3                                       data analyst
# 4       4                             reporting data analyst
# 5       5                                       data analyst
# 6       6                       business/data analyst (fp&a)
# 7       7                               data science analyst
# 8       8                                       data analyst
# 9       9                      data analyst, merchant health
# 10     10                                       data analyst
# 11     11                                       data analyst
# 12     12                                       data analyst
# 13     13                                senior data analyst
# ...

# %%
#master_token_df['title_split'] = master_token_df['title_split'].astype(str)
#master_token_df['title_split2'] = ' '.join(master_token_df['title_split'])

# %%
#master_token_df['title_split2'] = ' '.join(map(str, master_token_df['title_split']))
#master_token_df['title_split2'] = master_token_df['title_split'].apply(sent_tokenize)

# %%
master_token_df['title_split2']=master_token_df.title_split.apply(lambda x: ' '.join(list(x)))

# %%
master_token_df.head()
# Out:
#    index                                          job_title  \
# 0      0  data analyst, center on immigration and justic...
# 1      1                               quality data analyst
# 2      2  senior data analyst, insights & analytics team...
# 3      3                                       data analyst
# 4      4                             reporting data analyst
#
#               salary_estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      job_description                    size  \
# 0  Are you eager to roll up your sleeves and harn...    201 to 500 employees
# 1  Overview\n\nProvides analytical and technical ...        10000+ employees
# 2  We’re looking for a Senior Data Analyst who ha...  1001 to 5000 employees
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...    201 to 500 employees
# ...

# %%
c = master_token_df.title_split2.unique()

# %%
master_token_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8132 entries, 0 to 1969
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               8132 non-null   int64
#  1   job_title           8132 non-null   object
#  2   salary_estimate     6162 non-null   object
#  3   job_description     8132 non-null   object
#  4   size                6162 non-null   object
#  5   type_of_ownership   6162 non-null   object
#  6   industry            6162 non-null   object
#  7   sector              6162 non-null   object
#  8   revenue             6162 non-null   object
#  9   schedule_type       1961 non-null   object
#  10  work_from_home      993 non-null    object
#  11  salary              382 non-null    object
#  12  description_tokens  1970 non-null   object
#  13  title_split         8132 non-null   object
#  14  title_split2        8132 non-null   object
# dtypes: int64(1), object(14)
# ...

# %%
#to replace key words
master_token_df['title_split2'] = master_token_df['title_split2'].replace(['data analyst', 'data analyst analytics', 'analyst',
       'data',
       'analyst data',
       'data analyst data data',
       'data analyst data',
       'data analytics analyst', 'analytics data analyst', '',
       'analyst data analyst', 'analyst data analytics',
       'data data analyst',
       'data analyst analyst', 'data data analyst data',
       'data analyst analytics data analytics',
       'analyst data analytics data analyst',
       'data analyst data analytics',
       'analyst data data',
       'data analyst data analytics analytics',
       'data analyst data science', 'data analytics',
       'data analyst data analyst',
       'analytics analyst data', 'analyst analytics', 'data data',
       'analyst analyst data',
       'analytics data',
       'data data analytics', 'analyst analyst',
       'analytics data analytics', 
       'data analytics data',
       'analytics analyst', 'analyst analyst data analyst', 'analytics'
       ], 'data analyst')

# %%
master_token_df['title_split2'] = master_token_df['title_split2'].replace([
       'data science analyst', 'analyst data science',
       'data science',
       'data scientist data analytics analyst',
       'science data analyst',
       'data analyst scientist', 'data scientist',
       'analyst data science analytics',
        'data scientist analyst',
       'data analyst data science analytics',
       'data analyst data science',
       'scientist data analyst', 
       'analyst data scientist', 
       'data scientist analytics', 'scientist',
       'data scientist data science', 'data data scientist',
       'analytics data scientist', 'data scientist data',
       'data scientist analytics data', 'scientist data analytics',
       'data science analytics'
       'data science data science', 'data science data scientist'
       'data science analytics', 'data science data science',
       'data scientist data science analytics', 'scientist data',
       'scientist scientist', 'scientist science',
       'scientist data science', 'science scientist',
       'analytics data science', 'data scientist data analytics',
       'science data scientist', 'data scientist scientist',
       'data analyst science', 'data data analytics', 'science',
       'analytics science', 'scientist scientist data',
       'analyst scientist', 'scientist scientist science',
       'data data science data',
       'data scientist data scientist', 'scientist analytics',
       'data data science', 'science data science',
       'data scientist science',
       'data analytics data scientist', 'data science data',
       'data analyst data scientist'
       ,'data science data scientist', 'data science analytics'], 'data scientist')

# %%
master_token_df.title_split2.unique()
# Out:
# array(['data analyst', 'data scientist'], dtype=object)

# %%
master_token_df['title_split2'].unique()
# Out:
# array(['data analyst', 'data scientist'], dtype=object)

# %%
master_token_df.tail()
# Out:
#       index                                          job_title  \
# 1965   1965        senior performance marketing (data analyst)
# 1966   1966                 data analyst, developer operations
# 1967   1967  data science/data analyst internship - summer ...
# 1968   1968            2023 internship- associate data analyst
# 1969   1969                                   jr. data analyst
#
#      salary_estimate                                    job_description size  \
# 1965             NaN  At Edward Jones, we help clients achieve their...  NaN
# 1966             NaN  Summary:\n\nMeta Platforms, Inc. (Meta), forme...  NaN
# 1967             NaN  Description\n\nWho are we...\n\nAt Koch Indust...  NaN
# 1968             NaN  2023 Internship- Associate Data Analyst\n\nDes...  NaN
# 1969             NaN  Staffigo is in the business of providing IT Co...  NaN
#
#      type_of_ownership industry sector revenue schedule_type work_from_home  \
# ...

# %%
master_token_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8132 entries, 0 to 1969
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               8132 non-null   int64
#  1   job_title           8132 non-null   object
#  2   salary_estimate     6162 non-null   object
#  3   job_description     8132 non-null   object
#  4   size                6162 non-null   object
#  5   type_of_ownership   6162 non-null   object
#  6   industry            6162 non-null   object
#  7   sector              6162 non-null   object
#  8   revenue             6162 non-null   object
#  9   schedule_type       1961 non-null   object
#  10  work_from_home      993 non-null    object
#  11  salary              382 non-null    object
#  12  description_tokens  1970 non-null   object
#  13  title_split         8132 non-null   object
#  14  title_split2        8132 non-null   object
# dtypes: int64(1), object(14)
# ...

# %%
master_token_df.groupby(master_df['title_split2']).count()
# Out:
#                 index  job_title  salary_estimate  job_description  size  \
# title_split2
# data analyst     6227       6227             4308             6227  4308
# data scientist   1905       1905             1854             1905  1854
#
#                 type_of_ownership  industry  sector  revenue  schedule_type  \
# title_split2
# data analyst                 4308      4308    4308     4308           1910
# data scientist               1854      1854    1854     1854             51
#
#                 work_from_home  salary  description_tokens  title_split
# title_split2
# data analyst               964     371                1919         6227
# data scientist              29      11                  51         1905
