# %%
import pandas as pd

# %%
import nltk

# %%
Data_analyst= pd.read_csv('dataset/DataAnalyst.csv')

# %%
Data_analyst.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
# Import Libraries
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
#nltk.download('punkt')   # Required for tokenization
#nltk.download('wordnet') # Required for lemmatization
nltk.download('popular')
from nltk.corpus import stopwords
# Instantiate
lemmatizer = WordNetLemmatizer()
# Create our own stop words
stop_words = (                                        \
    "\n ’ sleeves company and of for in to a or years l   \
    other were that data to drive policy we at with our   \
    firm follows under consolidated have these over   \
    include billion million december which an le from \
    certain le — million had show apple including     \
    as noncurrent current total three are on not is   \
    involving millions shows centers contains      "  \
             ).split()
# Exclusion list of punctuations and numbers
exclist = string.punctuation + string.digits
# Print the exclusion list
print(exclist)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/akshaytayde/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/akshaytayde/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/akshaytayde/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/akshaytayde/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/akshaytayde/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# ...

# %%
# Create a Function
def clean_texts(text):
    """ Function to perform preprocessing """
    
    # Convert to lower cases
    text = text.lower()
    
    # Remove punctuations and numbers
    text = text.translate(str.maketrans("", "", exclist))
    
    
    
    # Tokenization
    tokens = word_tokenize(text)
        
    # Lemmatization
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    # Remove stop words
    tokens = [token for token in tokens if token not in stop_words]
    
    # Join tokens
    clean_text = " ".join(tokens)
    
    # Return the output
    return clean_text
# Apply the function to all disclosures
Data_analyst['Job Description'] = Data_analyst['Job Description'].apply(clean_texts)
# View the first 5 rows
Data_analyst.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  you eager roll up your sleeve harness change d...     3.2
# 1  overview provides analytical technical support...     3.8
# 2  re looking senior analyst who ha love mentorsh...     3.4
# 3  requisition numberrr remoteyes collaborate cre...     4.1
# 4  about fanduel group fanduel group worldclass t...     3.9
#
# ...

# %%
firstrow= Data_analyst['Job Description'][0]
firstrow
# Out:
# 'you eager roll up your sleeve harness change do you enjoy sifting through complex datasets illuminate trend insight do you see yourself working valuesdriven organization vision tackle the most pressing injustice day looking hire bright hardworking creative individual strong management skill demonstrated commitment immigrant right the analyst will assist analysis reporting need veras center immigration justice cij working across it project future vera initiative who founded the vera institute independent nonpartisan nonprofit organization combine expertise research technical assistance demonstration project assist leader government civil society examine justice practice improve the system people rely justice safety study problem impede human dignity justice pilot solution once transformative achievable engage diverse community informed debate harness the power evidence effective practice what doing helping build movementamong government leader advocate the immigration legal service c
# ...

# %%
Data_analyst['description_words'] = Data_analyst["Job Description"].apply(word_tokenize)
Data_analyst
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
Data_analyst['description_words'] = Data_analyst['description_words'].apply(lambda x: [item for item in x if item not in stop_words])
Data_analyst
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# ...

# %%
Data_analyst['description_words'][0]
# Out:
# ['you',
#  'eager',
#  'roll',
#  'up',
#  'your',
#  'sleeve',
#  'harness',
#  'change',
#  'do',
#  'you',
#  'enjoy',
#  'sifting',
#  'through',
#  'complex',
#  'datasets',
#  'illuminate',
#  'trend',
#  'insight',
#  'do',
#  'you',
#  'see',
#  'yourself',
#  'working',
#  'valuesdriven',
#  'organization',
#  'vision',
#  'tackle',
#  'the',
#  'most',
#  'pressing',
#  'injustice',
#  'day',
#  'looking',
#  'hire',
#  'bright',
#  'hardworking',
#  'creative',
#  'individual',
#  'strong',
#  'management',
#  'skill',
#  'demonstrated',
#  'commitment',
#  'immigrant',
#  'right',
#  'the',
#  'analyst',
#  'will',
#  'assist',
#  'analysis',
#  'reporting',
#  'need',
#  'veras',
#  'center',
#  'immigration',
#  'justice',
#  'cij',
#  'working',
#  'across',
#  'it',
#  'project',
#  'future',
#  'vera',
#  'initiative',
#  'who',
#  'founded',
#  'the',
#  'vera',
#  'institute',
#  'independent',
#  'nonpartisan',
#  'nonprofit',
#  'organization',
#  'combine',
# ...

# %%
from nltk import FreqDist

# %%
nltk.FreqDist(Data_analyst['description_words'][0])
# Out:
# FreqDist({'the': 25, 'justice': 11, 'you': 9, 'will': 9, 'vera': 9, 'working': 8, 'project': 8, 'immigration': 7, 'cij': 7, 'program': 7, ...})

# %%
my_languages = ["abap", "actionscript", "ada", "algol", "alice", "apl", "asp", "aspnet", "assembly" "language",
                "assembly language", "awk", "bbc", "bbcbasic", "bbc basic", "c", "c++", "c#", "cobol", "d", "delphi",
                "dreamweaver", "erlang", "elixir", "erlang and elixir", "f#", "forth", "fortran", "functional", "programming",
                "functional programming", "go", "haskell", "html", "idl", "idl", "intercal", "java", "javascript", "node", "js",
                "node.js", "jquery", "bootstrap" "labview","lisp","metaquotes language","metaquoteslanguage","ml","modula-3",
                "msaccess","ms access","mysql","nxt-g","object-oriented programming","objective-c","ocaml","pascal","perl",
                "php","pl/sql","postgresql","postscript","prolog","puredata","python","r","rapidweaver","ravendb","rexx",
                "ruby on rails","Rubyonrails","s-plus","sas","scala","sed","sgml","simula","smalltalk","smil","snobol",
                "sql","sqlite","ssi","stata","swift","tcl/tk","tex and latex","texandlatex","unified modeling language",
                "unix shells","unixshells","verilog","vhdl","visualbasi","visual basis","vrml","wap/wml","xml","xsl",'Communication, collaboration, and presentation skills',"Problem-solving","Research","Attention to detail","An analytical mindset","An affinity for numbers",
                "Good organizational skills","ability to meet deadlines","methodical and logical approach","business intelligence","analytics software","Tableau","SAS","RapidMiner","data profiling","requirement gathering","data visualization","deploy commercially viable statistical models"]

# %%
#softandhardskills
#sskills=['Communication, collaboration, and presentation skills',"Problem-solving","Research","Attention to detail","An analytical mindset","An affinity for numbers","Good organizational skills","ability to meet deadlines","methodical and logical approach"]

# %%
#hskils=["business intelligence","analytics software","Tableau","SAS","RapidMiner","data profiling","requirement gathering","data visualization","deploy commercially viable statistical models"]

# %%
Data_analyst['description_words'] = Data_analyst['description_words'].apply(lambda x: [item for item in x if item in my_languages])

# %%
Data_analyst['description_words'][0]
# Out:
# ['sql', 'r', 'python', 'sql', 'r', 'python', 'programming']

# %%
nltk.FreqDist(Data_analyst['description_words'][0])
# Out:
# FreqDist({'sql': 2, 'r': 2, 'python': 2, 'programming': 1})

# %%
Data_analyst.head(5)
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  you eager roll up your sleeve harness change d...     3.2
# 1  overview provides analytical technical support...     3.8
# 2  re looking senior analyst who ha love mentorsh...     3.4
# 3  requisition numberrr remoteyes collaborate cre...     4.1
# 4  about fanduel group fanduel group worldclass t...     3.9
#
# ...
